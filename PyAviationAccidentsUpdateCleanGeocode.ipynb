# %%
#*******************************************************************************************
 #
 #  File Name:  PyAviationAccidentsUpdateCleanGeocode.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, PyAviationAccidentsUpdateCleanGeocode.ipynb, 
 #      uses Pandas as well as other methods to update, clean, and geocode extracted 
 #      data for use.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  10/18/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import PySubRoutines as subroutine

import PyAviationAccidentsConstants as local_constant
import PyAviationAccidentsFunctions as local_function
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'PyAviationAccidentsGeocodeAPIExtract.ipynb'

# %%
log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('PyAviationAccidentsGeocodeAPIExtract')

# %% [markdown]
# # <br> **Section 1: Data Preparation**

# %% [markdown]
# ## **1.1: Read CSV Files**

# %%
aviationAccidentsDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_ACCIDENTS_DATA_CSV_FILE)

aviationAccidentsDataFrame \
    = aviationAccidentsDataFrame \
        .drop \
            (aviationAccidentsDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (aviationAccidentsDataFrame)

# %%
aviationAccidentsNarrativesDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_ACCIDENTS_DOCUMENTS_CSV_FILE)

aviationAccidentsNarrativesDataFrame \
    = aviationAccidentsNarrativesDataFrame \
        .drop \
            (aviationAccidentsNarrativesDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (aviationAccidentsNarrativesDataFrame)

# %% [markdown]
# ## **1.2: Display Initial DataFrames**

# %%
captionString \
    = 'Table 1.2.1: Aviation Accidents (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (aviationAccidentsDataFrame.head(10), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_66f1a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_66f1a_row0_col0, #T_66f1a_row0_col1, #T_66f1a_row0_col2, #T_66f1a_row0_col3, #T_66f1a_row0_col4, #T_66f1a_row0_col5, #T_66f1a_row0_col6, #T_66f1a_row0_col7, #T_66f1a_row0_col8, #T_66f1a_row0_col9, #T_66f1a_row0_col10, #T_66f1a_row0_col11, #T_66f1a_row0_col12, #T_66f1a_row0_col13, #T_66f1a_row0_col14, #T_66f1a_row0_col15, #T_66f1a_row0_col16, #T_66f1a_row0_col17, #T_66f1a_row0_col18, #T_66f1a_row0_col19, #T_66f1a_row0_col20, #T_66f1a_row0_col21, #T_66f1a_row0_col22, #T_66f1a_row0_col23, #T_66f1a_row1_col0, #T_66f1a_row1_col1, #T_66f1a_row1_col2, #T_66f1a_row1_col3, #T_66f1a_row1_col4, #T_66f1a_row1_col5, #T_66f1a_row1_col6, #T_66f1a_row1_col7, #T_66f1a_row1_col8, #T_66f1a_row1_col9, #T_66f1a_row1_col10, #T_66f1a_row1_col11, #T_66f1a_row1_col12, #T_66f1a_row1_col13, #T_66f1a_row1_col14, #T_66f1a_row1_col15, #T_66f1a_row1_col16, #T_66f1a_row1_col17, #T_66f1a_row1_col18, #T_66f1a_row1_col19, #T_66f1a_row1_col20, #T_66f1a_row1_col21, #T_66f1a_row1_col22, #T_66f1a_row1_col23, #T_66f1a_row2_col0, #T_66f1a_row2_col1, #T_66f1a_row2_col2, #T_66f1a_row2_col3, #T_66f1a_row2_col4, #T_66f1a_row2_col5, #T_66f1a_row2_col6, #T_66f1a_row2_col7, #T_66f1a_row2_col8, #T_66f1a_row2_col9, #T_66f1a_row2_col10, #T_66f1a_row2_col11, #T_66f1a_row2_col12, #T_66f1a_row2_col13, #T_66f1a_row2_col14, #T_66f1a_row2_col15, #T_66f1a_row2_col16, #T_66f1a_row2_col17, #T_66f1a_row2_col18, #T_66f1a_row2_col19, #T_66f1a_row2_col20, #T_66f1a_row2_col21, #T_66f1a_row2_col22, #T_66f1a_row2_col23, #T_66f1a_row3_col0, #T_66f1a_row3_col1, #T_66f1a_row3_col2, #T_66f1a_row3_col3, #T_66f1a_row3_col4, #T_66f1a_row3_col5, #T_66f1a_row3_col6, #T_66f1a_row3_col7, #T_66f1a_row3_col8, #T_66f1a_row3_col9, #T_66f1a_row3_col10, #T_66f1a_row3_col11, #T_66f1a_row3_col12, #T_66f1a_row3_col13, #T_66f1a_row3_col14, #T_66f1a_row3_col15, #T_66f1a_row3_col16, #T_66f1a_row3_col17, #T_66f1a_row3_col18, #T_66f1a_row3_col19, #T_66f1a_row3_col20, #T_66f1a_row3_col21, #T_66f1a_row3_col22, #T_66f1a_row3_col23, #T_66f1a_row4_col0, #T_66f1a_row4_col1, #T_66f1a_row4_col2, #T_66f1a_row4_col3, #T_66f1a_row4_col4, #T_66f1a_row4_col5, #T_66f1a_row4_col6, #T_66f1a_row4_col7, #T_66f1a_row4_col8, #T_66f1a_row4_col9, #T_66f1a_row4_col10, #T_66f1a_row4_col11, #T_66f1a_row4_col12, #T_66f1a_row4_col13, #T_66f1a_row4_col14, #T_66f1a_row4_col15, #T_66f1a_row4_col16, #T_66f1a_row4_col17, #T_66f1a_row4_col18, #T_66f1a_row4_col19, #T_66f1a_row4_col20, #T_66f1a_row4_col21, #T_66f1a_row4_col22, #T_66f1a_row4_col23, #T_66f1a_row5_col0, #T_66f1a_row5_col1, #T_66f1a_row5_col2, #T_66f1a_row5_col3, #T_66f1a_row5_col4, #T_66f1a_row5_col5, #T_66f1a_row5_col6, #T_66f1a_row5_col7, #T_66f1a_row5_col8, #T_66f1a_row5_col9, #T_66f1a_row5_col10, #T_66f1a_row5_col11, #T_66f1a_row5_col12, #T_66f1a_row5_col13, #T_66f1a_row5_col14, #T_66f1a_row5_col15, #T_66f1a_row5_col16, #T_66f1a_row5_col17, #T_66f1a_row5_col18, #T_66f1a_row5_col19, #T_66f1a_row5_col20, #T_66f1a_row5_col21, #T_66f1a_row5_col22, #T_66f1a_row5_col23, #T_66f1a_row6_col0, #T_66f1a_row6_col1, #T_66f1a_row6_col2, #T_66f1a_row6_col3, #T_66f1a_row6_col4, #T_66f1a_row6_col5, #T_66f1a_row6_col6, #T_66f1a_row6_col7, #T_66f1a_row6_col8, #T_66f1a_row6_col9, #T_66f1a_row6_col10, #T_66f1a_row6_col11, #T_66f1a_row6_col12, #T_66f1a_row6_col13, #T_66f1a_row6_col14, #T_66f1a_row6_col15, #T_66f1a_row6_col16, #T_66f1a_row6_col17, #T_66f1a_row6_col18, #T_66f1a_row6_col19, #T_66f1a_row6_col20, #T_66f1a_row6_col21, #T_66f1a_row6_col22, #T_66f1a_row6_col23, #T_66f1a_row7_col0, #T_66f1a_row7_col1, #T_66f1a_row7_col2, #T_66f1a_row7_col3, #T_66f1a_row7_col4, #T_66f1a_row7_col5, #T_66f1a_row7_col6, #T_66f1a_row7_col7, #T_66f1a_row7_col8, #T_66f1a_row7_col9, #T_66f1a_row7_col10, #T_66f1a_row7_col11, #T_66f1a_row7_col12, #T_66f1a_row7_col13, #T_66f1a_row7_col14, #T_66f1a_row7_col15, #T_66f1a_row7_col16, #T_66f1a_row7_col17, #T_66f1a_row7_col18, #T_66f1a_row7_col19, #T_66f1a_row7_col20, #T_66f1a_row7_col21, #T_66f1a_row7_col22, #T_66f1a_row7_col23, #T_66f1a_row8_col0, #T_66f1a_row8_col1, #T_66f1a ...
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_66f1a">
#   <caption>Table 1.2.1: Aviation Accidents (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_66f1a_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_66f1a_level0_col1" class="col_heading level0 col1" >status</th>
#       <th id="T_66f1a_level0_col2" class="col_heading level0 col2" >acc_date</th>
#       <th id="T_66f1a_level0_col3" class="col_heading level0 col3" >acc_time</th>
#       <th id="T_66f1a_level0_col4" class="col_heading level0 col4" >acc_datetime</th>
#       <th id="T_66f1a_level0_col5" class="col_heading level0 col5" >type</th>
#       <th id="T_66f1a_level0_col6" class="col_heading level0 col6" >operator</th>
#       <th id="T_66f1a_level0_col7" class="col_heading level0 col7" >registration</th>
#       <th id="T_66f1a_level0_col8" class="col_heading level0 col8" >msn</th>
#       <th id="T_66f1a_level0_col9" class="col_heading level0 col9" >first_flight</th>
#       <th id="T_66f1a_level0_col10" class="col_heading level0 col10" >crew_fatalities</th>
#       <th id="T_66f1a_level0_col11" class="col_heading level0 col11" >crew_occupants</th>
#       <th id="T_66f1a_level0_col12" class="col_heading level0 col12" >passenger_fatalities</th>
#       <th id="T_66f1a_level0_col13" class="col_heading level0 col13" >passenger_occupants</th>
#       <th id="T_66f1a_level0_col14" class="col_heading level0 col14" >total_fatalities</th>
#       <th id="T_66f1a_level0_col15" class="col_heading level0 col15" >total_occupants</th>
#       <th id="T_66f1a_level0_col16" class="col_heading level0 col16" >aircraft_damage</th>
#       <th id="T_66f1a_level0_col17" class="col_heading level0 col17" >phase</th>
#       <th id="T_66f1a_level0_col18" class="col_heading level0 col18" >nature</th>
#       <th id="T_66f1a_level0_col19" class="col_heading level0 col19" >depart_airport</th>
#       <th id="T_66f1a_level0_col20" class="col_heading level0 col20" >destination_airport</th>
#       <th id="T_66f1a_level0_col21" class="col_heading level0 col21" >flight_number</th>
#       <th id="T_66f1a_level0_col22" class="col_heading level0 col22" >location</th>
#       <th id="T_66f1a_level0_col23" class="col_heading level0 col23" >classifications</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_66f1a_row0_col0" class="data row0 col0" >ACC100</td>
#       <td id="T_66f1a_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_66f1a_row0_col2" class="data row0 col2" >1972-01-07</td>
#       <td id="T_66f1a_row0_col3" class="data row0 col3" >12:10</td>
#       <td id="T_66f1a_row0_col4" class="data row0 col4" >1972-01-07 12:10:00</td>
#       <td id="T_66f1a_row0_col5" class="data row0 col5" >Sud Aviation SE-210 Caravelle VI-R</td>
#       <td id="T_66f1a_row0_col6" class="data row0 col6" >Iberia</td>
#       <td id="T_66f1a_row0_col7" class="data row0 col7" >EC-ATV</td>
#       <td id="T_66f1a_row0_col8" class="d

# %%
captionString \
    = 'Table 1.2.2: Aviation Accidents Narratives (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (aviationAccidentsNarrativesDataFrame.head(10), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_f68bd caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f68bd_row0_col0, #T_f68bd_row0_col1, #T_f68bd_row1_col0, #T_f68bd_row1_col1, #T_f68bd_row2_col0, #T_f68bd_row2_col1, #T_f68bd_row3_col0, #T_f68bd_row3_col1, #T_f68bd_row4_col0, #T_f68bd_row4_col1, #T_f68bd_row5_col0, #T_f68bd_row5_col1, #T_f68bd_row6_col0, #T_f68bd_row6_col1, #T_f68bd_row7_col0, #T_f68bd_row7_col1, #T_f68bd_row8_col0, #T_f68bd_row8_col1, #T_f68bd_row9_col0, #T_f68bd_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_f68bd">
#   <caption>Table 1.2.2: Aviation Accidents Narratives (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_f68bd_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_f68bd_level0_col1" class="col_heading level0 col1" >narrative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f68bd_row0_col0" class="data row0 col0" >ACC100</td>
#       <td id="T_f68bd_row0_col1" class="data row0 col1" >Iberia flight 602, a Caravelle VI-R passenger jet, was destroyed when it struck a mountainside of the Sierra de Atalayasa, near Ibiza Airport (IBZ), Spain. All 104 on board were killed.The aircraft had departed Madrid (MAD) on a domestic service to Valencia (VLC) and Ibiza Airport (IBZ). While flying an approach to runway 07 at Ibiza, the airplane struck a 415 m high mountain, 30 m below the summit.It was determined that the pilot had failed to maintain the minimum altitude for a visual approach to runway 07</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row1_col0" class="data row1 col0" >ACC101</td>
#       <td id="T_f68bd_row1_col1" class="data row1 col1" >Ran off the end of the runway during a training flight.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row2_col0" class="data row2 col0" >ACC102</td>
#       <td id="T_f68bd_row2_col1" class="data row2 col1" >Since its first flight on July 14, 1971, the VFW/Fokker VFW.614 prototype was engaged in several test flights. Changes were made following elevator flutter problems during test flights. For the flight on February 1, 1972 the airplane had been fitted with flutter dampers.The flight test called for an asymmetric flutter at 220 kt and 10,000 feet. This time the flutter could not be eliminated by slowing down and the crew abandoned the aircraft. Co-pilot Hans Bardill was killed when his parachute failed to open. The airplane entered a vertical dive and crashed.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row3_col0" class="data row3 col0" >ACC103</td>
#       <td id="T_f68bd_row3_col1" class="data row3 col1" >The Caribou transport aircraft, carrying Lao military forces to a forward position, was making a normal landing approach when an obstruction was sighted on the runway. The pilot initiated a go-around but the left engine failed to respond and the aircraft's left wing contacted the ground causing the aircraft to pancake into the ground. One Lao Air Freight Specialist and one Lao military passenger were killed.The Caribou, which had been leased from the US Air Force (serial 61-2393), sustained major damage and, after the recovery of several components, was abandoned at the crash site.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row4_col0" class="data row4 col0" >ACC104</td>
#       <td id="T_f68bd_row4_col1" class="data row4 col1" >The Antonov lost control and crashed on approach to Mineralnye Vody's runway 12 when the pilot unintentionally applied reverse thrust at an altitude of 200 m, about 2000 m short of the runway.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row5_col0" class="data row5 col0" >ACC105</td>
#       <td id="T_f68bd_row5_col1" class="data row5 col1" >The Lockheed AC-130A Spectre gunship operated on a truck hunting mission over the Ho Chi Minh Trail. It was struck by one of three SA-2 surface to air missiles fired at the aircraft.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row6_col0" class="data row6 col0" >ACC106</td>
#       <td id="T_f68bd_row6_col1" class="data row6 col1" >The pilot miscalculated the fuel consumption and flying time. The plane was eventually ditched 215 miles off the coast.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row7_col0" class="data row7 col0" >ACC107</td>
#       <td id="T_f68bd_row7_col1" class="data row7 col1" >The AC-130E gunship was attacking a convoy of trucks on the Ho Chi Minh Trail in Laos. During the attack it was struck by 57 mm ground fire. The airplane was flying at an altitude of 7500 feet at the time. The pilot attempted to reach Thailand, but a fire had started on the starboard wing. The crew parachuted to safety.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row8_col0" class="data row8 col0" >ACC108</td>
#       <td id="T_f68bd_row8_col1" class="data row8 col1" >The Fairchild AC-119 was sent on a mission to An Loc to destroy an ammunition drop that had landed on enemy territory. It was flying at 4700 feet when it was struck by 37 mm anti aircraft fire. One of the wings caught fire. Seven occupants bailed out safely before the aircraft crashed.</td>
#     </tr>
#     <tr>
#       <td id="T_f68bd_row9_col0" class="data row9 col0" >ACC109</td>
#       <td id="T_f68bd_row9_col1" class="data row9 col1" >The Yak-40 took off from Irkutsk Airport (IKT) at 22:29. While on approach the crew were given the weather information that was current at 23:15. The controller had not received more recent weather information, despite his requests. He knew the weather had deteriorated but he passed the older weather info on to the crew. On finals the flight entered an area with a wet snow storm, 1000 m visibility severe buffeting and wind gusts of 10-14 m/s. An intense downdraft caused the plane to contact trees. The airplane crashed and burned.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <br> **Section 2: Update Aviation Accident Data**

# %% [markdown]
# ## **2.1 Drop DataFrame Columns**

# %%
aviationAccidentsDataFrame \
    = aviationAccidentsDataFrame \
        .drop \
            (['status',
              'acc_time', 
              'acc_datetime', 
              'msn',
              'first_flight',
              'crew_fatalities',
              'crew_occupants',
              'passenger_fatalities',
              'passenger_occupants',
              'flight_number',
              'classifications'], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (aviationAccidentsDataFrame)

# %% [markdown]
# ## **2.2: Remove Military Incidents and Unknown Flight Phases**

# %%
updatedAviationAccidentsDataFrame \
    = function \
        .ReturnDataFrameRowsWithoutValue \
            (aviationAccidentsDataFrame,
             'nature',
             ['Military'])

updatedAviationAccidentsDataFrame \
    = function \
        .ReturnDataFrameRowsWithoutValue \
            (updatedAviationAccidentsDataFrame,
             'phase',
             ['Unknown (UNK)'])


updatedAviationAccidentsDataFrame \
    = function \
        .ReturnDataFrameRowsWithoutValue \
            (updatedAviationAccidentsDataFrame,
             'total_fatalities',
             [0])



log_function \
    .DebugReturnObjectWriteObject \
        (updatedAviationAccidentsDataFrame)

# %%
updatedAviationAccidentsNarrativesDataFrame \
    = function \
        .ReturnDataFrameRowsWithValue \
            (aviationAccidentsNarrativesDataFrame,
             'accident_id',
             updatedAviationAccidentsDataFrame['accident_id'].tolist())


log_function \
    .DebugReturnObjectWriteObject \
        (updatedAviationAccidentsNarrativesDataFrame)

# %% [markdown]
# ## **2.3: Updated DataFrame Information**

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'Table 2.3.1: Updated Aviation Accidents Information (1972-2022):\n' 
         + '\033[0m')

updatedAviationAccidentsDataFrame \
    .info \
        (verbose = True,
         memory_usage = True, 
         show_counts = True)
# Out:
# Table 2.3.1: Updated Aviation Accidents Information (1972-2022):
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777 entries, 0 to 2046
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accident_id          777 non-null    object
#  1   acc_date             777 non-null    object
#  2   type                 777 non-null    object
#  3   operator             777 non-null    object
#  4   registration         777 non-null    object
#  5   total_fatalities     777 non-null    int64
#  6   total_occupants      777 non-null    int64
#  7   aircraft_damage      777 non-null    object
#  8   phase                777 non-null    object
#  9   nature               777 non-null    object
#  10  depart_airport       777 non-null    object
#  11  destination_airport  777 non-null    object
#  12  location             777 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 85.0+ KB

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'Table 2.3.2: Updated Aviation Accidents Narratives Information (1972-2022):\n' 
         + '\033[0m')

updatedAviationAccidentsNarrativesDataFrame \
    .info \
        (verbose = True,
         memory_usage = True, 
         show_counts = True)
# Out:
# Table 2.3.2: Updated Aviation Accidents Narratives Information (1972-2022):
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777 entries, 0 to 2046
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   accident_id  777 non-null    object
#  1   narrative    777 non-null    object
# dtypes: object(2)
# memory usage: 18.2+ KB

# %% [markdown]
# ## **2.4: Display Updated DataFrames**

# %%
captionString \
    = 'Table 2.4.1: Updated Aviation Accidents (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (updatedAviationAccidentsDataFrame.head(10), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_0e292 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0e292_row0_col0, #T_0e292_row0_col1, #T_0e292_row0_col2, #T_0e292_row0_col3, #T_0e292_row0_col4, #T_0e292_row0_col5, #T_0e292_row0_col6, #T_0e292_row0_col7, #T_0e292_row0_col8, #T_0e292_row0_col9, #T_0e292_row0_col10, #T_0e292_row0_col11, #T_0e292_row0_col12, #T_0e292_row1_col0, #T_0e292_row1_col1, #T_0e292_row1_col2, #T_0e292_row1_col3, #T_0e292_row1_col4, #T_0e292_row1_col5, #T_0e292_row1_col6, #T_0e292_row1_col7, #T_0e292_row1_col8, #T_0e292_row1_col9, #T_0e292_row1_col10, #T_0e292_row1_col11, #T_0e292_row1_col12, #T_0e292_row2_col0, #T_0e292_row2_col1, #T_0e292_row2_col2, #T_0e292_row2_col3, #T_0e292_row2_col4, #T_0e292_row2_col5, #T_0e292_row2_col6, #T_0e292_row2_col7, #T_0e292_row2_col8, #T_0e292_row2_col9, #T_0e292_row2_col10, #T_0e292_row2_col11, #T_0e292_row2_col12, #T_0e292_row3_col0, #T_0e292_row3_col1, #T_0e292_row3_col2, #T_0e292_row3_col3, #T_0e292_row3_col4, #T_0e292_row3_col5, #T_0e292_row3_col6, #T_0e292_row3_col7, #T_0e292_row3_col8, #T_0e292_row3_col9, #T_0e292_row3_col10, #T_0e292_row3_col11, #T_0e292_row3_col12, #T_0e292_row4_col0, #T_0e292_row4_col1, #T_0e292_row4_col2, #T_0e292_row4_col3, #T_0e292_row4_col4, #T_0e292_row4_col5, #T_0e292_row4_col6, #T_0e292_row4_col7, #T_0e292_row4_col8, #T_0e292_row4_col9, #T_0e292_row4_col10, #T_0e292_row4_col11, #T_0e292_row4_col12, #T_0e292_row5_col0, #T_0e292_row5_col1, #T_0e292_row5_col2, #T_0e292_row5_col3, #T_0e292_row5_col4, #T_0e292_row5_col5, #T_0e292_row5_col6, #T_0e292_row5_col7, #T_0e292_row5_col8, #T_0e292_row5_col9, #T_0e292_row5_col10, #T_0e292_row5_col11, #T_0e292_row5_col12, #T_0e292_row6_col0, #T_0e292_row6_col1, #T_0e292_row6_col2, #T_0e292_row6_col3, #T_0e292_row6_col4, #T_0e292_row6_col5, #T_0e292_row6_col6, #T_0e292_row6_col7, #T_0e292_row6_col8, #T_0e292_row6_col9, #T_0e292_row6_col10, #T_0e292_row6_col11, #T_0e292_row6_col12, #T_0e292_row7_col0, #T_0e292_row7_col1, #T_0e292_row7_col2, #T_0e292_row7_col3, #T_0e292_row7_col4, #T_0e292_row7_col5, #T_0e292_row7_col6, #T_0e292_row7_col7, #T_0e292_row7_col8, #T_0e292_row7_col9, #T_0e292_row7_col10, #T_0e292_row7_col11, #T_0e292_row7_col12, #T_0e292_row8_col0, #T_0e292_row8_col1, #T_0e292_row8_col2, #T_0e292_row8_col3, #T_0e292_row8_col4, #T_0e292_row8_col5, #T_0e292_row8_col6, #T_0e292_row8_col7, #T_0e292_row8_col8, #T_0e292_row8_col9, #T_0e292_row8_col10, #T_0e292_row8_col11, #T_0e292_row8_col12, #T_0e292_row9_col0, #T_0e292_row9_col1, #T_0e292_row9_col2, #T_0e292_row9_col3, #T_0e292_row9_col4, #T_0e292_row9_col5, #T_0e292_row9_col6, #T_0e292_row9_col7, #T_0e292_row9_col8, #T_0e292_row9_col9, #T_0e292_row9_col10, #T_0e292_row9_col11, #T_0e292_row9_col12 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_0e292">
#   <caption>Table 2.4.1: Updated Aviation Accidents (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_0e292_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_0e292_level0_col1" class="col_heading level0 col1" >acc_date</th>
#       <th id="T_0e292_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_0e292_level0_col3" class="col_heading level0 col3" >operator</th>
#       <th id="T_0e292_level0_col4" class="col_heading level0 col4" >registration</th>
#       <th id="T_0e292_level0_col5" class="col_heading level0 col5" >total_fatalities</th>
#       <th id="T_0e292_level0_col6" class="col_heading level0 col6" >total_occupants</th>
#       <th id="T_0e292_level0_col7" class="col_heading level0 col7" >aircraft_damage</th>
#       <th id="T_0e292_level0_col8" class="col_heading level0 col8" >phase</th>
#       <th id="T_0e292_level0_col9" class="col_heading level0 col9" >nature</th>
#       <th id="T_0e292_level0_col10" class="col_heading level0 col10" >depart_airport</th>
#       <th id="T_0e292_level0_col11" class="col_heading level0 col11" >destination_airport</th>
#       <th id="T_0e292_level0_col12" class="col_heading level0 col12" >location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0e292_row0_col0" class="data row0 col0" >ACC100</td>
#       <td id="T_0e292_row0_col1" class="data row0 col1" >1972-01-07</td>
#       <td id="T_0e292_row0_col2" class="data row0 col2" >Sud Aviation SE-210 Caravelle VI-R</td>
#       <td id="T_0e292_row0_col3" class="data row0 col3" >Iberia</td>
#       <td id="T_0e292_row0_col4" class="data row0 col4" >EC-ATV</td>
#       <td id="T_0e292_row0_col5" class="data row0 col5" >104</td>
#       <td id="T_0e292_row0_col6" class="data row0 col6" >104</td>
#       <td id="T_0e292_row0_col7" class="data row0 col7" >Destroyed</td>
#       <td id="T_0e292_row0_col8" class="data row0 col8" >Approach (APR)</td>
#       <td id="T_0e292_row0_col9" class="data row0 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_0e292_row0_col10" class="data row0 col10" >Valencia Airport (VLC/LEVC), Spain</td>
#       <td id="T_0e292_row0_col11" class="data row0 col11" >Ibiza Airport (IBZ/LEIB), Spain</td>
#       <td id="T_0e292_row0_col12" class="data row0 col12" >ca 15 km W of Ibiza Airport (IBZ) (Spain)</td>
#     </tr>
#     <tr>
#       <td id="T_0e292_row1_col0" class="data row1 col0" >ACC102</td>
#       <td id="T_0e292_row1_col1" class="data row1 col1" >1972-02-01</td>
#       <td id="T_0e292_row1_col2" class="data row1 col2" >VFW/Fokker VFW.614</td>
#       <td id="T_0e292_row1_col3" class="data row1 col3" >VFW-Fokker</td>
#       <td id="T_0e292_row1_col4" class="data row1 col4" >D-BABA</td>
#       <td id="T_0e292_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_0e292_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_0e292_row1_col7" class="data row1 col7" >Damaged beyond repair</td>
#       <td id="T_0e292_row1_col8" class="data row1 col8" >Maneuvering (MNV)</td>
#       <td id="T_0e292_row1_col9" class="data row1 col9" >Test</td>
#       <td id="T_0e292_row1_col10" class="data row1 col10" >Bremen Airport (BRE/EDDW), Germany</td>
#       <td id="T_0e292_row1_col11" class="data row1 col11" >Bremen Airport (BRE/EDDW), Germany</td>
#       <td id="T_0e292_row1_col12" class="data row1 col12" >near Bremen Airport (BRE) (Germany)</td>
#     </tr>
#     <tr>
#       <td id="T_0e292_row2_col0" class="data row2 col0" >ACC109</td>
#       <td id="T_0e292_row2_col1" class="data row2 col1" >1972-05-04</td>
#       <td id="T_0e292_row2_col2" class="data row2 col2" >Yakovlev Yak-40</td>
#       <td id="T_0e292_row2_col3" class="data row2 col3" >Aeroflot, East Siberia Civil Aviation Directorate</td>
#       <td id="T_0e292_row2_col4" class="data row2 col4" >CCCP-87778</td>
#       <td id="T_0e292_row2_col5" class="data row2 col5" >18</td>
#       <td id="T_0e292_row2_col6" class="data row2 col6" >18</td>
#       <td id="T_0e292_row2_col7" class="data row2 col7" >Destroyed</td>
#       <td id="T_0e292_row2_col8" class="data row2 col8" >Approach (APR)</td>
#       <td id="T_0e292_row2_col9" class="data row2 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_0e292_row2_col10" class="data row2 col10" >Irkutsk Airport (IKT/UIII), Russia</td>
#       <td id="T_0e292_row2_col11" class="data row2 col11" >Bratsk Airport (BTK/UIBB), Russia</td>
#       <td id="T_0e292_row2_col12" class="data row2 col12" >1,2 km (0.8 mls) from Bratsk Airport (BTK) (Russia)</td>
#     </tr>
#     <tr>
#       <td id="T_0e292_row3_col0" class="data row3 col0" >ACC110</td>
#       <td id="T_0e292_row3_col1" class="data row3 col1" >1972-05-08</td>
#       <td id="T_0e292_row3_col2" class="data row3 col2" >Douglas VC-47J (DC-3)</td>
#       <td id="T_0e292_row3_col3" class="data row3 col3" >Aerotécnica</td>
#       <td id="T_0e292_row3_col4" class="data row3 col4" >YV-C-GAI</td>
#       <td id="T_0e292_row3_col5" class="data row3 col5" >6</td>
#       <td id="T_0e292_row3_col6" class="data row3 col6" >6</td>
#       <td id="T_0e292_row3_col7" class="data row3 col7" >Damaged beyond repair</td>
#       <td id="T_0e292_row3_col8" class="data row3 col8" >En route (ENR)</td>
#       <td id="T_0e292_row3_col9"

# %%
captionString \
    = 'Table 2.4.2: Updated Aviation Accidents Narratives (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (updatedAviationAccidentsNarrativesDataFrame.head(10), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_f375d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f375d_row0_col0, #T_f375d_row0_col1, #T_f375d_row1_col0, #T_f375d_row1_col1, #T_f375d_row2_col0, #T_f375d_row2_col1, #T_f375d_row3_col0, #T_f375d_row3_col1, #T_f375d_row4_col0, #T_f375d_row4_col1, #T_f375d_row5_col0, #T_f375d_row5_col1, #T_f375d_row6_col0, #T_f375d_row6_col1, #T_f375d_row7_col0, #T_f375d_row7_col1, #T_f375d_row8_col0, #T_f375d_row8_col1, #T_f375d_row9_col0, #T_f375d_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_f375d">
#   <caption>Table 2.4.2: Updated Aviation Accidents Narratives (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_f375d_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_f375d_level0_col1" class="col_heading level0 col1" >narrative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f375d_row0_col0" class="data row0 col0" >ACC100</td>
#       <td id="T_f375d_row0_col1" class="data row0 col1" >Iberia flight 602, a Caravelle VI-R passenger jet, was destroyed when it struck a mountainside of the Sierra de Atalayasa, near Ibiza Airport (IBZ), Spain. All 104 on board were killed.The aircraft had departed Madrid (MAD) on a domestic service to Valencia (VLC) and Ibiza Airport (IBZ). While flying an approach to runway 07 at Ibiza, the airplane struck a 415 m high mountain, 30 m below the summit.It was determined that the pilot had failed to maintain the minimum altitude for a visual approach to runway 07</td>
#     </tr>
#     <tr>
#       <td id="T_f375d_row1_col0" class="data row1 col0" >ACC102</td>
#       <td id="T_f375d_row1_col1" class="data row1 col1" >Since its first flight on July 14, 1971, the VFW/Fokker VFW.614 prototype was engaged in several test flights. Changes were made following elevator flutter problems during test flights. For the flight on February 1, 1972 the airplane had been fitted with flutter dampers.The flight test called for an asymmetric flutter at 220 kt and 10,000 feet. This time the flutter could not be eliminated by slowing down and the crew abandoned the aircraft. Co-pilot Hans Bardill was killed when his parachute failed to open. The airplane entered a vertical dive and crashed.</td>
#     </tr>
#     <tr>
#       <td id="T_f375d_row2_col0" class="data row2 col0" >ACC109</td>
#       <td id="T_f375d_row2_col1" class="data row2 col1" >The Yak-40 took off from Irkutsk Airport (IKT) at 22:29. While on approach the crew were given the weather information that was current at 23:15. The controller had not received more recent weather information, despite his requests. He knew the weather had deteriorated but he passed the older weather info on to the crew. On finals the flight entered an area with a wet snow storm, 1000 m visibility severe buffeting and wind gusts of 10-14 m/s. An intense downdraft caused the plane to contact trees. The airplane crashed and burned.</td>
#     </tr>
#     <tr>
#       <td id="T_f375d_row3_col0" class="data row3 col0" >ACC110</td>
#       <td id="T_f375d_row3_col1" class="data row3 col1" >The DC-3 struck a mountain near Rio Orinoco, about thirty minutes after takeoff from Ciudad Bolívar, Venezuela. Conflicting reports say the airplane was headed for La Centella or the Cuchivero mines.</td>
#     </tr>
#     <tr>
#       <td id="T_f375d_row4_col0" class="data row4 col0" >ACC112</td>
#       <td id="T_f375d_row4_col1" class="data row4 col1" >Crashed into the sea when approaching Lobito in conditions below visual minima. The airplane operated on a domestic flight from Luanda (LAD) to Sá da Bandeira (now Lubango).</td>
#     </tr>
#     <tr>
#       <td id="T_f375d_row5_col0" class="data row5 col0" >ACC113</td>
#       <td id="T_f375d_row5_col1" class="data row5 col1" >The DHC-6 Twin Otter fell off to the left after taking off from Helgoland Airport (HGL), Germany. The airplane fell from a height of 60 m and came down about 200 m left of the runway.</td>
#     </tr>
#     <tr>
#       <td id="T_f375d_row6_col0" class="data row6 col0" >ACC116</td>
#       <td id="T_f375d_row6_col1" class="data row6 col1" >The aircraft was one of a number of aircraft of this type used for the carriage of company employees and goods for Messerschmitt-Bolkow-Blohm GmbH.A twice-weekly charter service was operated from Germany to Warton Aerodrome in the United Kingdom or, alternatively, to Blackpool civil airport.D-CASY left Munich on the morning of 29 June 1972 and landed at 09:04 hrs at Blackpool, as Customs facilities were not available at that time at Warton.During the day the aircraft remained on the ground at Blackpool and for most of the time the captain and co-pilot were with it. At 15:20 hrs six of the eight passengers to be carried on the return trip to Germany arrived at Blackpool Airport and, as it was raining, sat in the aircraft, the Auxiliary Power Unit (APU) of which was running. Two more passengers were expected. A flight plan was prepared for Munich via Rotterdam and filed at 15:30 hrs.The two passengers did not turn up at the appointed time and the APU was shut down while the passengers and crew waited in the aircraft. About 16:30 hrs word was received that the two extra passengers were not coming. This meant that extra fuel could be accommodated and a new flight plan direct to Munich could be prepared. It was filed by the first officer, while the captain carried out the pre-flight check. The captain then started the APU and sat in the left hand seat with the first officer in the right hand seat and, according to the passenger who survived the accident, indicated that the first officer should operate the aircraft in command under supervision.The aircraft taxied out and lined up and the surviving passenger saw the right hand wing slat extended when the first officer applied power with the brakes 'on' at the start of the take-off. The port side wing slat and the flaps were outside this passenger's field of view.During the take-off run the aircraft reached its normal rotation speed in the usual distance. However, although the aircraft was travelling fast enough, rotation did not take place and it did not become airborne. The surviving passenger saw the first officer's hand holding the throttles fully open and wondered why the aircraft did not take-off. Then he saw a gesture from the captain indicating that the take-off should be abandoned. The first officer immediately closed the throttles. Observers on the aerodrome heard the engine noise die down approximately 300 metres from the end of the runway. Subsequently brake marks were found commencing in the same area. Braking was not effective, however, and the aircraft left the end of the runway at high speed, in a level attitude with its nosewheel and main wheels in contact with the ground. Shortly before the first impact the surviving passenger noticed the captain's hand on the controls and saw aileron movement.The first collision occurred when the starboard wing tip struck and severed a post supporting one of the airfield runway approach lights. The aircraft continued, colliding with and badly distorting the double track railway lines at the edge of the airfield. The nose wheel of the landing gear was broken off by this impact and some structural damage was done to the underside of the fuselage. Almost immediately beyond the railway lines the aircraft broke through a wall and collided with a row of single storey masonry chalets in the adjacent holiday camp, demolishing six of them and setting them on fire.The wings were broken off during this impact, spilling fuel over the area, but the main part of the aircraft continued its progress, sustaining further structural damage as it did so. The forward part of the fuselage, including the flight deck, was twisted to starboard and progressively destroyed. The final impact brought the aircraft to rest against a second row of chalets which were also badly damaged. The wreckage caught fire and was destroyed. The crew

# %%
log_subroutine \
    .PrintAndLogWriteText \
        ('\033[1m' \
         + 'There are now {:,} complete aviation accident records from 1972 to 2022.' \
             .format(len(updatedAviationAccidentsDataFrame))
         + '\n\n'
         + '\033[0m')
# Out:
# There are now 777 complete aviation accident records from 1972 to 2022.

# %% [markdown]
# # <br> **Section 3: Clean Aviation Accidents Data**

# %% [markdown]
# ## **3.1: Clean Aircraft Operators**

# %%
cleanAviationAccidentsDataFrame \
    = updatedAviationAccidentsDataFrame.copy()

# %%
cleanAviationAccidentsDataFrame \
    ['operator'] \
        = local_function \
            .ReturnCleanAircraftOperators \
                (updatedAviationAccidentsDataFrame \
                    ['operator'])


log_function \
    .DebugReturnObjectWriteObject \
        (cleanAviationAccidentsDataFrame \
            ['operator'])

# %% [markdown]
# ## **3.2: Clean Aircraft Types**

# %%
cleanAviationAccidentsDataFrame \
    ['type'] \
        = local_function \
            .ReturnCleanAircraftTypes \
                (updatedAviationAccidentsDataFrame \
                    ['type'])

    
log_function \
    .DebugReturnObjectWriteObject \
        (cleanAviationAccidentsDataFrame \
            ['type'])

# %% [markdown]
# ## **3.3: Display Clean DataFrame**

# %%
captionString \
    = 'Table 3.3.1: Aviation Accidents (Clean Data) (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (cleanAviationAccidentsDataFrame.head(10), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_6fd44 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_6fd44_row0_col0, #T_6fd44_row0_col1, #T_6fd44_row0_col2, #T_6fd44_row0_col3, #T_6fd44_row0_col4, #T_6fd44_row0_col5, #T_6fd44_row0_col6, #T_6fd44_row0_col7, #T_6fd44_row0_col8, #T_6fd44_row0_col9, #T_6fd44_row0_col10, #T_6fd44_row0_col11, #T_6fd44_row0_col12, #T_6fd44_row1_col0, #T_6fd44_row1_col1, #T_6fd44_row1_col2, #T_6fd44_row1_col3, #T_6fd44_row1_col4, #T_6fd44_row1_col5, #T_6fd44_row1_col6, #T_6fd44_row1_col7, #T_6fd44_row1_col8, #T_6fd44_row1_col9, #T_6fd44_row1_col10, #T_6fd44_row1_col11, #T_6fd44_row1_col12, #T_6fd44_row2_col0, #T_6fd44_row2_col1, #T_6fd44_row2_col2, #T_6fd44_row2_col3, #T_6fd44_row2_col4, #T_6fd44_row2_col5, #T_6fd44_row2_col6, #T_6fd44_row2_col7, #T_6fd44_row2_col8, #T_6fd44_row2_col9, #T_6fd44_row2_col10, #T_6fd44_row2_col11, #T_6fd44_row2_col12, #T_6fd44_row3_col0, #T_6fd44_row3_col1, #T_6fd44_row3_col2, #T_6fd44_row3_col3, #T_6fd44_row3_col4, #T_6fd44_row3_col5, #T_6fd44_row3_col6, #T_6fd44_row3_col7, #T_6fd44_row3_col8, #T_6fd44_row3_col9, #T_6fd44_row3_col10, #T_6fd44_row3_col11, #T_6fd44_row3_col12, #T_6fd44_row4_col0, #T_6fd44_row4_col1, #T_6fd44_row4_col2, #T_6fd44_row4_col3, #T_6fd44_row4_col4, #T_6fd44_row4_col5, #T_6fd44_row4_col6, #T_6fd44_row4_col7, #T_6fd44_row4_col8, #T_6fd44_row4_col9, #T_6fd44_row4_col10, #T_6fd44_row4_col11, #T_6fd44_row4_col12, #T_6fd44_row5_col0, #T_6fd44_row5_col1, #T_6fd44_row5_col2, #T_6fd44_row5_col3, #T_6fd44_row5_col4, #T_6fd44_row5_col5, #T_6fd44_row5_col6, #T_6fd44_row5_col7, #T_6fd44_row5_col8, #T_6fd44_row5_col9, #T_6fd44_row5_col10, #T_6fd44_row5_col11, #T_6fd44_row5_col12, #T_6fd44_row6_col0, #T_6fd44_row6_col1, #T_6fd44_row6_col2, #T_6fd44_row6_col3, #T_6fd44_row6_col4, #T_6fd44_row6_col5, #T_6fd44_row6_col6, #T_6fd44_row6_col7, #T_6fd44_row6_col8, #T_6fd44_row6_col9, #T_6fd44_row6_col10, #T_6fd44_row6_col11, #T_6fd44_row6_col12, #T_6fd44_row7_col0, #T_6fd44_row7_col1, #T_6fd44_row7_col2, #T_6fd44_row7_col3, #T_6fd44_row7_col4, #T_6fd44_row7_col5, #T_6fd44_row7_col6, #T_6fd44_row7_col7, #T_6fd44_row7_col8, #T_6fd44_row7_col9, #T_6fd44_row7_col10, #T_6fd44_row7_col11, #T_6fd44_row7_col12, #T_6fd44_row8_col0, #T_6fd44_row8_col1, #T_6fd44_row8_col2, #T_6fd44_row8_col3, #T_6fd44_row8_col4, #T_6fd44_row8_col5, #T_6fd44_row8_col6, #T_6fd44_row8_col7, #T_6fd44_row8_col8, #T_6fd44_row8_col9, #T_6fd44_row8_col10, #T_6fd44_row8_col11, #T_6fd44_row8_col12, #T_6fd44_row9_col0, #T_6fd44_row9_col1, #T_6fd44_row9_col2, #T_6fd44_row9_col3, #T_6fd44_row9_col4, #T_6fd44_row9_col5, #T_6fd44_row9_col6, #T_6fd44_row9_col7, #T_6fd44_row9_col8, #T_6fd44_row9_col9, #T_6fd44_row9_col10, #T_6fd44_row9_col11, #T_6fd44_row9_col12 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_6fd44">
#   <caption>Table 3.3.1: Clean Aviation Accidents (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_6fd44_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_6fd44_level0_col1" class="col_heading level0 col1" >acc_date</th>
#       <th id="T_6fd44_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_6fd44_level0_col3" class="col_heading level0 col3" >operator</th>
#       <th id="T_6fd44_level0_col4" class="col_heading level0 col4" >registration</th>
#       <th id="T_6fd44_level0_col5" class="col_heading level0 col5" >total_fatalities</th>
#       <th id="T_6fd44_level0_col6" class="col_heading level0 col6" >total_occupants</th>
#       <th id="T_6fd44_level0_col7" class="col_heading level0 col7" >aircraft_damage</th>
#       <th id="T_6fd44_level0_col8" class="col_heading level0 col8" >phase</th>
#       <th id="T_6fd44_level0_col9" class="col_heading level0 col9" >nature</th>
#       <th id="T_6fd44_level0_col10" class="col_heading level0 col10" >depart_airport</th>
#       <th id="T_6fd44_level0_col11" class="col_heading level0 col11" >destination_airport</th>
#       <th id="T_6fd44_level0_col12" class="col_heading level0 col12" >location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6fd44_row0_col0" class="data row0 col0" >ACC100</td>
#       <td id="T_6fd44_row0_col1" class="data row0 col1" >1972-01-07</td>
#       <td id="T_6fd44_row0_col2" class="data row0 col2" >Sud Aviation SE-210</td>
#       <td id="T_6fd44_row0_col3" class="data row0 col3" >Iberia</td>
#       <td id="T_6fd44_row0_col4" class="data row0 col4" >EC-ATV</td>
#       <td id="T_6fd44_row0_col5" class="data row0 col5" >104</td>
#       <td id="T_6fd44_row0_col6" class="data row0 col6" >104</td>
#       <td id="T_6fd44_row0_col7" class="data row0 col7" >Destroyed</td>
#       <td id="T_6fd44_row0_col8" class="data row0 col8" >Approach (APR)</td>
#       <td id="T_6fd44_row0_col9" class="data row0 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_6fd44_row0_col10" class="data row0 col10" >Valencia Airport (VLC/LEVC), Spain</td>
#       <td id="T_6fd44_row0_col11" class="data row0 col11" >Ibiza Airport (IBZ/LEIB), Spain</td>
#       <td id="T_6fd44_row0_col12" class="data row0 col12" >ca 15 km W of Ibiza Airport (IBZ) (Spain)</td>
#     </tr>
#     <tr>
#       <td id="T_6fd44_row1_col0" class="data row1 col0" >ACC102</td>
#       <td id="T_6fd44_row1_col1" class="data row1 col1" >1972-02-01</td>
#       <td id="T_6fd44_row1_col2" class="data row1 col2" >VFW-Fokker 614</td>
#       <td id="T_6fd44_row1_col3" class="data row1 col3" >VFW-Fokker</td>
#       <td id="T_6fd44_row1_col4" class="data row1 col4" >D-BABA</td>
#       <td id="T_6fd44_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_6fd44_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_6fd44_row1_col7" class="data row1 col7" >Damaged beyond repair</td>
#       <td id="T_6fd44_row1_col8" class="data row1 col8" >Maneuvering (MNV)</td>
#       <td id="T_6fd44_row1_col9" class="data row1 col9" >Test</td>
#       <td id="T_6fd44_row1_col10" class="data row1 col10" >Bremen Airport (BRE/EDDW), Germany</td>
#       <td id="T_6fd44_row1_col11" class="data row1 col11" >Bremen Airport (BRE/EDDW), Germany</td>
#       <td id="T_6fd44_row1_col12" class="data row1 col12" >near Bremen Airport (BRE) (Germany)</td>
#     </tr>
#     <tr>
#       <td id="T_6fd44_row2_col0" class="data row2 col0" >ACC109</td>
#       <td id="T_6fd44_row2_col1" class="data row2 col1" >1972-05-04</td>
#       <td id="T_6fd44_row2_col2" class="data row2 col2" >Yakovlev YAK-40</td>
#       <td id="T_6fd44_row2_col3" class="data row2 col3" >Aeroflot</td>
#       <td id="T_6fd44_row2_col4" class="data row2 col4" >CCCP-87778</td>
#       <td id="T_6fd44_row2_col5" class="data row2 col5" >18</td>
#       <td id="T_6fd44_row2_col6" class="data row2 col6" >18</td>
#       <td id="T_6fd44_row2_col7" class="data row2 col7" >Destroyed</td>
#       <td id="T_6fd44_row2_col8" class="data row2 col8" >Approach (APR)</td>
#       <td id="T_6fd44_row2_col9" class="data row2 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_6fd44_row2_col10" class="data row2 col10" >Irkutsk Airport (IKT/UIII), Russia</td>
#       <td id="T_6fd44_row2_col11" class="data row2 col11" >Bratsk Airport (BTK/UIBB), Russia</td>
#       <td id="T_6fd44_row2_col12" class="data row2 col12" >1,2 km (0.8 mls) from Bratsk Airport (BTK) (Russia)</td>
#     </tr>
#     <tr>
#       <td id="T_6fd44_row3_col0" class="data row3 col0" >ACC110</td>
#       <td id="T_6fd44_row3_col1" class="data row3 col1" >1972-05-08</td>
#       <td id="T_6fd44_row3_col2" class="data row3 col2" >Douglas DC-3</td>
#       <td id="T_6fd44_row3_col3" class="data row3 col3" >Aerotécnica</td>
#       <td id="T_6fd44_row3_col4" class="data row3 col4" >YV-C-GAI</td>
#       <td id="T_6fd44_row3_col5" class="data row3 col5" >6</td>
#       <td id="T_6fd44_row3_col6" class="data row3 col6" >6</td>
#       <td id="T_6fd44_row3_col7" class="data row3 col7" >Damaged beyond repair</td>
#       <td id="T_6fd44_row3_col8" class="data row3 col8" >En route (ENR)</td>
#       <td id="T_6fd44_row3_col9" class="data row3 col9" >Domestic Non Scheduled Passenger</td>
#       <td

# %% [markdown]
# # <br> **Section 4: Assemble Geographic Information**

# %% [markdown]
# ## **4.1: Departure Airports**

# %%
departureAirportsDataFrame \
    = local_function \
        .ReturnGeocodeDataFrameForAirports \
            (cleanAviationAccidentsDataFrame \
                 ['depart_airport'])

# %% [markdown]
# ## **4.2: Display Departure Airports**

# %%
captionString \
    = 'Table 4.2.1: Departure Airports for each Accident (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (departureAirportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_33a4c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_33a4c_row0_col0, #T_33a4c_row0_col1, #T_33a4c_row0_col2, #T_33a4c_row0_col3, #T_33a4c_row0_col4, #T_33a4c_row0_col5, #T_33a4c_row0_col6, #T_33a4c_row0_col7, #T_33a4c_row1_col0, #T_33a4c_row1_col1, #T_33a4c_row1_col2, #T_33a4c_row1_col3, #T_33a4c_row1_col4, #T_33a4c_row1_col5, #T_33a4c_row1_col6, #T_33a4c_row1_col7, #T_33a4c_row2_col0, #T_33a4c_row2_col1, #T_33a4c_row2_col2, #T_33a4c_row2_col3, #T_33a4c_row2_col4, #T_33a4c_row2_col5, #T_33a4c_row2_col6, #T_33a4c_row2_col7, #T_33a4c_row3_col0, #T_33a4c_row3_col1, #T_33a4c_row3_col2, #T_33a4c_row3_col3, #T_33a4c_row3_col4, #T_33a4c_row3_col5, #T_33a4c_row3_col6, #T_33a4c_row3_col7, #T_33a4c_row4_col0, #T_33a4c_row4_col1, #T_33a4c_row4_col2, #T_33a4c_row4_col3, #T_33a4c_row4_col4, #T_33a4c_row4_col5, #T_33a4c_row4_col6, #T_33a4c_row4_col7, #T_33a4c_row5_col0, #T_33a4c_row5_col1, #T_33a4c_row5_col2, #T_33a4c_row5_col3, #T_33a4c_row5_col4, #T_33a4c_row5_col5, #T_33a4c_row5_col6, #T_33a4c_row5_col7, #T_33a4c_row6_col0, #T_33a4c_row6_col1, #T_33a4c_row6_col2, #T_33a4c_row6_col3, #T_33a4c_row6_col4, #T_33a4c_row6_col5, #T_33a4c_row6_col6, #T_33a4c_row6_col7, #T_33a4c_row7_col0, #T_33a4c_row7_col1, #T_33a4c_row7_col2, #T_33a4c_row7_col3, #T_33a4c_row7_col4, #T_33a4c_row7_col5, #T_33a4c_row7_col6, #T_33a4c_row7_col7, #T_33a4c_row8_col0, #T_33a4c_row8_col1, #T_33a4c_row8_col2, #T_33a4c_row8_col3, #T_33a4c_row8_col4, #T_33a4c_row8_col5, #T_33a4c_row8_col6, #T_33a4c_row8_col7, #T_33a4c_row9_col0, #T_33a4c_row9_col1, #T_33a4c_row9_col2, #T_33a4c_row9_col3, #T_33a4c_row9_col4, #T_33a4c_row9_col5, #T_33a4c_row9_col6, #T_33a4c_row9_col7, #T_33a4c_row10_col0, #T_33a4c_row10_col1, #T_33a4c_row10_col2, #T_33a4c_row10_col3, #T_33a4c_row10_col4, #T_33a4c_row10_col5, #T_33a4c_row10_col6, #T_33a4c_row10_col7, #T_33a4c_row11_col0, #T_33a4c_row11_col1, #T_33a4c_row11_col2, #T_33a4c_row11_col3, #T_33a4c_row11_col4, #T_33a4c_row11_col5, #T_33a4c_row11_col6, #T_33a4c_row11_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_33a4c">
#   <caption>Table 4.2.1: Departure Airports for each Accident (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_33a4c_level0_col0" class="col_heading level0 col0" >icao</th>
#       <th id="T_33a4c_level0_col1" class="col_heading level0 col1" >iata</th>
#       <th id="T_33a4c_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_33a4c_level0_col3" class="col_heading level0 col3" >state</th>
#       <th id="T_33a4c_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_33a4c_level0_col5" class="col_heading level0 col5" >country_code</th>
#       <th id="T_33a4c_level0_col6" class="col_heading level0 col6" >lat</th>
#       <th id="T_33a4c_level0_col7" class="col_heading level0 col7" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33a4c_row0_col0" class="data row0 col0" >LEVC</td>
#       <td id="T_33a4c_row0_col1" class="data row0 col1" >VLC</td>
#       <td id="T_33a4c_row0_col2" class="data row0 col2" >Valencia Airport</td>
#       <td id="T_33a4c_row0_col3" class="data row0 col3" ></td>
#       <td id="T_33a4c_row0_col4" class="data row0 col4" >Spain</td>
#       <td id="T_33a4c_row0_col5" class="data row0 col5" >ES</td>
#       <td id="T_33a4c_row0_col6" class="data row0 col6" >39.49</td>
#       <td id="T_33a4c_row0_col7" class="data row0 col7" >-0.48</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row1_col0" class="data row1 col0" >EDDW</td>
#       <td id="T_33a4c_row1_col1" class="data row1 col1" >BRE</td>
#       <td id="T_33a4c_row1_col2" class="data row1 col2" >Bremen Airport</td>
#       <td id="T_33a4c_row1_col3" class="data row1 col3" ></td>
#       <td id="T_33a4c_row1_col4" class="data row1 col4" >Germany</td>
#       <td id="T_33a4c_row1_col5" class="data row1 col5" >DE</td>
#       <td id="T_33a4c_row1_col6" class="data row1 col6" >53.05</td>
#       <td id="T_33a4c_row1_col7" class="data row1 col7" >8.79</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row2_col0" class="data row2 col0" >UIII</td>
#       <td id="T_33a4c_row2_col1" class="data row2 col1" >IKT</td>
#       <td id="T_33a4c_row2_col2" class="data row2 col2" >Irkutsk Airport</td>
#       <td id="T_33a4c_row2_col3" class="data row2 col3" ></td>
#       <td id="T_33a4c_row2_col4" class="data row2 col4" >Russia</td>
#       <td id="T_33a4c_row2_col5" class="data row2 col5" >RU</td>
#       <td id="T_33a4c_row2_col6" class="data row2 col6" >52.27</td>
#       <td id="T_33a4c_row2_col7" class="data row2 col7" >104.39</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row3_col0" class="data row3 col0" >SVCB</td>
#       <td id="T_33a4c_row3_col1" class="data row3 col1" >CBL</td>
#       <td id="T_33a4c_row3_col2" class="data row3 col2" >Ciudad Bolívar Airport</td>
#       <td id="T_33a4c_row3_col3" class="data row3 col3" ></td>
#       <td id="T_33a4c_row3_col4" class="data row3 col4" >Venezuela</td>
#       <td id="T_33a4c_row3_col5" class="data row3 col5" >VE</td>
#       <td id="T_33a4c_row3_col6" class="data row3 col6" >8.12</td>
#       <td id="T_33a4c_row3_col7" class="data row3 col7" >-63.54</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row4_col0" class="data row4 col0" >FNLU</td>
#       <td id="T_33a4c_row4_col1" class="data row4 col1" >LAD</td>
#       <td id="T_33a4c_row4_col2" class="data row4 col2" >Luanda Airport</td>
#       <td id="T_33a4c_row4_col3" class="data row4 col3" ></td>
#       <td id="T_33a4c_row4_col4" class="data row4 col4" >Angola</td>
#       <td id="T_33a4c_row4_col5" class="data row4 col5" >AO</td>
#       <td id="T_33a4c_row4_col6" class="data row4 col6" >-8.86</td>
#       <td id="T_33a4c_row4_col7" class="data row4 col7" >13.23</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row5_col0" class="data row5 col0" >EDXH</td>
#       <td id="T_33a4c_row5_col1" class="data row5 col1" >HGL</td>
#       <td id="T_33a4c_row5_col2" class="data row5 col2" >Helgoland Airfield</td>
#       <td id="T_33a4c_row5_col3" class="data row5 col3" ></td>
#       <td id="T_33a4c_row5_col4" class="data row5 col4" >Germany</td>
#       <td id="T_33a4c_row5_col5" class="data row5 col5" >DE</td>
#       <td id="T_33a4c_row5_col6" class="data row5 col6" >54.19</td>
#       <td id="T_33a4c_row5_col7" class="data row5 col7" >7.92</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row6_col0" class="data row6 col0" >EGNH</td>
#       <td id="T_33a4c_row6_col1" class="data row6 col1" >BLK</td>
#       <td id="T_33a4c_row6_col2" class="data row6 col2" >Blackpool Airport</td>
#       <td id="T_33a4c_row6_col3" class="data row6 col3" ></td>
#       <td id="T_33a4c_row6_col4" class="data row6 col4" >United Kingdom</td>
#       <td id="T_33a4c_row6_col5" class="data row6 col5" >GB</td>
#       <td id="T_33a4c_row6_col6" class="data row6 col6" >53.77</td>
#       <td id="T_33a4c_row6_col7" class="data row6 col7" >-3.03</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row7_col0" class="data row7 col0" >UHSH</td>
#       <td id="T_33a4c_row7_col1" class="data row7 col1" >OHH</td>
#       <td id="T_33a4c_row7_col2" class="data row7 col2" >Okha Airport</td>
#       <td id="T_33a4c_row7_col3" class="data row7 col3" ></td>
#       <td id="T_33a4c_row7_col4" class="data row7 col4" >Russia</td>
#       <td id="T_33a4c_row7_col5" class="data row7 col5" >RU</td>
#       <td id="T_33a4c_row7_col6" class="data row7 col6" >53.52</td>
#       <td id="T_33a4c_row7_col7" class="data row7 col7" >142.89</td>
#     </tr>
#     <tr>
#       <td id="T_33a4c_row8_col0" class="data row8 col0" >KALM</td>
#       <td id="T_33a4c_row8_col1" class="data row8 col1" >ALM</td>
#       <td id="T_33a4c_row8_col2" class="data row8 col2" >Alamogordo Municipal Airport</td>
#       <td id="T_33a4c_row8_col3" class="data row8 col3" >NM</td>
#       <td id="T_33a4c_row8_col4" class="data row8 col4" >United States of America</td>
#       <td id="T_33a4c_row8_col5" class="data row8 col5" >US</td>
#       <td id="T_33a4c_row8_col6" class="data row8 col6" >32.84</td>
#       <td id="T_33a4c_row8_col7" cla

# %% [markdown]
# ## **4.3: Destination Airports**

# %%
destinationAirportsDataFrame \
    = local_function \
        .ReturnGeocodeDataFrameForAirports \
            (cleanAviationAccidentsDataFrame \
                 ['destination_airport'])

# %% [markdown]
# ## **4.4: Display Destination Airports**

# %%
captionString \
    = 'Table 4.4.1: Destination Airports for each Accident (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (destinationAirportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_0b352 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0b352_row0_col0, #T_0b352_row0_col1, #T_0b352_row0_col2, #T_0b352_row0_col3, #T_0b352_row0_col4, #T_0b352_row0_col5, #T_0b352_row0_col6, #T_0b352_row0_col7, #T_0b352_row1_col0, #T_0b352_row1_col1, #T_0b352_row1_col2, #T_0b352_row1_col3, #T_0b352_row1_col4, #T_0b352_row1_col5, #T_0b352_row1_col6, #T_0b352_row1_col7, #T_0b352_row2_col0, #T_0b352_row2_col1, #T_0b352_row2_col2, #T_0b352_row2_col3, #T_0b352_row2_col4, #T_0b352_row2_col5, #T_0b352_row2_col6, #T_0b352_row2_col7, #T_0b352_row3_col0, #T_0b352_row3_col1, #T_0b352_row3_col2, #T_0b352_row3_col3, #T_0b352_row3_col4, #T_0b352_row3_col5, #T_0b352_row3_col6, #T_0b352_row3_col7, #T_0b352_row4_col0, #T_0b352_row4_col1, #T_0b352_row4_col2, #T_0b352_row4_col3, #T_0b352_row4_col4, #T_0b352_row4_col5, #T_0b352_row4_col6, #T_0b352_row4_col7, #T_0b352_row5_col0, #T_0b352_row5_col1, #T_0b352_row5_col2, #T_0b352_row5_col3, #T_0b352_row5_col4, #T_0b352_row5_col5, #T_0b352_row5_col6, #T_0b352_row5_col7, #T_0b352_row6_col0, #T_0b352_row6_col1, #T_0b352_row6_col2, #T_0b352_row6_col3, #T_0b352_row6_col4, #T_0b352_row6_col5, #T_0b352_row6_col6, #T_0b352_row6_col7, #T_0b352_row7_col0, #T_0b352_row7_col1, #T_0b352_row7_col2, #T_0b352_row7_col3, #T_0b352_row7_col4, #T_0b352_row7_col5, #T_0b352_row7_col6, #T_0b352_row7_col7, #T_0b352_row8_col0, #T_0b352_row8_col1, #T_0b352_row8_col2, #T_0b352_row8_col3, #T_0b352_row8_col4, #T_0b352_row8_col5, #T_0b352_row8_col6, #T_0b352_row8_col7, #T_0b352_row9_col0, #T_0b352_row9_col1, #T_0b352_row9_col2, #T_0b352_row9_col3, #T_0b352_row9_col4, #T_0b352_row9_col5, #T_0b352_row9_col6, #T_0b352_row9_col7, #T_0b352_row10_col0, #T_0b352_row10_col1, #T_0b352_row10_col2, #T_0b352_row10_col3, #T_0b352_row10_col4, #T_0b352_row10_col5, #T_0b352_row10_col6, #T_0b352_row10_col7, #T_0b352_row11_col0, #T_0b352_row11_col1, #T_0b352_row11_col2, #T_0b352_row11_col3, #T_0b352_row11_col4, #T_0b352_row11_col5, #T_0b352_row11_col6, #T_0b352_row11_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_0b352">
#   <caption>Table 4.4.1: Destination Airports for each Accident (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_0b352_level0_col0" class="col_heading level0 col0" >icao</th>
#       <th id="T_0b352_level0_col1" class="col_heading level0 col1" >iata</th>
#       <th id="T_0b352_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_0b352_level0_col3" class="col_heading level0 col3" >state</th>
#       <th id="T_0b352_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_0b352_level0_col5" class="col_heading level0 col5" >country_code</th>
#       <th id="T_0b352_level0_col6" class="col_heading level0 col6" >lat</th>
#       <th id="T_0b352_level0_col7" class="col_heading level0 col7" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b352_row0_col0" class="data row0 col0" >LEIB</td>
#       <td id="T_0b352_row0_col1" class="data row0 col1" >IBZ</td>
#       <td id="T_0b352_row0_col2" class="data row0 col2" >Ibiza Airport</td>
#       <td id="T_0b352_row0_col3" class="data row0 col3" ></td>
#       <td id="T_0b352_row0_col4" class="data row0 col4" >Spain</td>
#       <td id="T_0b352_row0_col5" class="data row0 col5" >ES</td>
#       <td id="T_0b352_row0_col6" class="data row0 col6" >38.87</td>
#       <td id="T_0b352_row0_col7" class="data row0 col7" >1.37</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row1_col0" class="data row1 col0" >EDDW</td>
#       <td id="T_0b352_row1_col1" class="data row1 col1" >BRE</td>
#       <td id="T_0b352_row1_col2" class="data row1 col2" >Bremen Airport</td>
#       <td id="T_0b352_row1_col3" class="data row1 col3" ></td>
#       <td id="T_0b352_row1_col4" class="data row1 col4" >Germany</td>
#       <td id="T_0b352_row1_col5" class="data row1 col5" >DE</td>
#       <td id="T_0b352_row1_col6" class="data row1 col6" >53.05</td>
#       <td id="T_0b352_row1_col7" class="data row1 col7" >8.79</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row2_col0" class="data row2 col0" >UIBB</td>
#       <td id="T_0b352_row2_col1" class="data row2 col1" >BTK</td>
#       <td id="T_0b352_row2_col2" class="data row2 col2" >Bratsk Airport</td>
#       <td id="T_0b352_row2_col3" class="data row2 col3" ></td>
#       <td id="T_0b352_row2_col4" class="data row2 col4" >Russia</td>
#       <td id="T_0b352_row2_col5" class="data row2 col5" >RU</td>
#       <td id="T_0b352_row2_col6" class="data row2 col6" >56.37</td>
#       <td id="T_0b352_row2_col7" class="data row2 col7" >101.70</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row3_col0" class="data row3 col0" >xxxx</td>
#       <td id="T_0b352_row3_col1" class="data row3 col1" >xxx</td>
#       <td id="T_0b352_row3_col2" class="data row3 col2" >La Centella</td>
#       <td id="T_0b352_row3_col3" class="data row3 col3" ></td>
#       <td id="T_0b352_row3_col4" class="data row3 col4" >Venezuela</td>
#       <td id="T_0b352_row3_col5" class="data row3 col5" >VE</td>
#       <td id="T_0b352_row3_col6" class="data row3 col6" >9.85</td>
#       <td id="T_0b352_row3_col7" class="data row3 col7" >-64.76</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row4_col0" class="data row4 col0" >FNLB</td>
#       <td id="T_0b352_row4_col1" class="data row4 col1" >xxx</td>
#       <td id="T_0b352_row4_col2" class="data row4 col2" >Lobito Airport</td>
#       <td id="T_0b352_row4_col3" class="data row4 col3" ></td>
#       <td id="T_0b352_row4_col4" class="data row4 col4" >Angola</td>
#       <td id="T_0b352_row4_col5" class="data row4 col5" >AO</td>
#       <td id="T_0b352_row4_col6" class="data row4 col6" >-12.37</td>
#       <td id="T_0b352_row4_col7" class="data row4 col7" >13.54</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row5_col0" class="data row5 col0" >EDWG</td>
#       <td id="T_0b352_row5_col1" class="data row5 col1" >AGE</td>
#       <td id="T_0b352_row5_col2" class="data row5 col2" >Wangerooge Airfield</td>
#       <td id="T_0b352_row5_col3" class="data row5 col3" ></td>
#       <td id="T_0b352_row5_col4" class="data row5 col4" >Germany</td>
#       <td id="T_0b352_row5_col5" class="data row5 col5" >DE</td>
#       <td id="T_0b352_row5_col6" class="data row5 col6" >53.78</td>
#       <td id="T_0b352_row5_col7" class="data row5 col7" >7.91</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row6_col0" class="data row6 col0" >EHRD</td>
#       <td id="T_0b352_row6_col1" class="data row6 col1" >RTM</td>
#       <td id="T_0b352_row6_col2" class="data row6 col2" >Rotterdam Airport</td>
#       <td id="T_0b352_row6_col3" class="data row6 col3" ></td>
#       <td id="T_0b352_row6_col4" class="data row6 col4" >Netherlands</td>
#       <td id="T_0b352_row6_col5" class="data row6 col5" >NL</td>
#       <td id="T_0b352_row6_col6" class="data row6 col6" >51.96</td>
#       <td id="T_0b352_row6_col7" class="data row6 col7" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row7_col0" class="data row7 col0" >xxxx</td>
#       <td id="T_0b352_row7_col1" class="data row7 col1" >xxx</td>
#       <td id="T_0b352_row7_col2" class="data row7 col2" >Tsimmermanovka Airstrip</td>
#       <td id="T_0b352_row7_col3" class="data row7 col3" ></td>
#       <td id="T_0b352_row7_col4" class="data row7 col4" >Russia</td>
#       <td id="T_0b352_row7_col5" class="data row7 col5" >RU</td>
#       <td id="T_0b352_row7_col6" class="data row7 col6" >51.34</td>
#       <td id="T_0b352_row7_col7" class="data row7 col7" >139.25</td>
#     </tr>
#     <tr>
#       <td id="T_0b352_row8_col0" class="data row8 col0" >KALM</td>
#       <td id="T_0b352_row8_col1" class="data row8 col1" >ALM</td>
#       <td id="T_0b352_row8_col2" class="data row8 col2" >Alamogordo Municipal Airport</td>
#       <td id="T_0b352_row8_col3" class="data row8 col3" >NM</td>
#       <td id="T_0b352_row8_col4" class="data row8 col4" >United States of America</td>
#       <td id="T_0b352_row8_col5" class="data row8 col5" >US</td>
#       <td id="T_0b352_row8_col6" class="data row8 col6" >32.84</td>
#       <td id="T_0b352_row8_col7" class="d

# %% [markdown]
# ## **4.5: Aviation Accident Locations**

# %%
aviationAccidentLocationsDataFrame \
    = local_function \
        .ReturnGeocodeDataFrameForAccidents \
            (cleanAviationAccidentsDataFrame \
                ['location'])

# %% [markdown]
# ## **4.6: Display Aviation Accident Locations**

# %%
captionString \
    = 'Table 4.6.1: Aviation Accident Locations (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (aviationAccidentLocationsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_dded7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_dded7_row0_col0, #T_dded7_row0_col1, #T_dded7_row0_col2, #T_dded7_row0_col3, #T_dded7_row0_col4, #T_dded7_row0_col5, #T_dded7_row0_col6, #T_dded7_row0_col7, #T_dded7_row1_col0, #T_dded7_row1_col1, #T_dded7_row1_col2, #T_dded7_row1_col3, #T_dded7_row1_col4, #T_dded7_row1_col5, #T_dded7_row1_col6, #T_dded7_row1_col7, #T_dded7_row2_col0, #T_dded7_row2_col1, #T_dded7_row2_col2, #T_dded7_row2_col3, #T_dded7_row2_col4, #T_dded7_row2_col5, #T_dded7_row2_col6, #T_dded7_row2_col7, #T_dded7_row3_col0, #T_dded7_row3_col1, #T_dded7_row3_col2, #T_dded7_row3_col3, #T_dded7_row3_col4, #T_dded7_row3_col5, #T_dded7_row3_col6, #T_dded7_row3_col7, #T_dded7_row4_col0, #T_dded7_row4_col1, #T_dded7_row4_col2, #T_dded7_row4_col3, #T_dded7_row4_col4, #T_dded7_row4_col5, #T_dded7_row4_col6, #T_dded7_row4_col7, #T_dded7_row5_col0, #T_dded7_row5_col1, #T_dded7_row5_col2, #T_dded7_row5_col3, #T_dded7_row5_col4, #T_dded7_row5_col5, #T_dded7_row5_col6, #T_dded7_row5_col7, #T_dded7_row6_col0, #T_dded7_row6_col1, #T_dded7_row6_col2, #T_dded7_row6_col3, #T_dded7_row6_col4, #T_dded7_row6_col5, #T_dded7_row6_col6, #T_dded7_row6_col7, #T_dded7_row7_col0, #T_dded7_row7_col1, #T_dded7_row7_col2, #T_dded7_row7_col3, #T_dded7_row7_col4, #T_dded7_row7_col5, #T_dded7_row7_col6, #T_dded7_row7_col7, #T_dded7_row8_col0, #T_dded7_row8_col1, #T_dded7_row8_col2, #T_dded7_row8_col3, #T_dded7_row8_col4, #T_dded7_row8_col5, #T_dded7_row8_col6, #T_dded7_row8_col7, #T_dded7_row9_col0, #T_dded7_row9_col1, #T_dded7_row9_col2, #T_dded7_row9_col3, #T_dded7_row9_col4, #T_dded7_row9_col5, #T_dded7_row9_col6, #T_dded7_row9_col7, #T_dded7_row10_col0, #T_dded7_row10_col1, #T_dded7_row10_col2, #T_dded7_row10_col3, #T_dded7_row10_col4, #T_dded7_row10_col5, #T_dded7_row10_col6, #T_dded7_row10_col7, #T_dded7_row11_col0, #T_dded7_row11_col1, #T_dded7_row11_col2, #T_dded7_row11_col3, #T_dded7_row11_col4, #T_dded7_row11_col5, #T_dded7_row11_col6, #T_dded7_row11_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_dded7">
#   <caption>Table 4.6.1: Aviation Accident Locations (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_dded7_level0_col0" class="col_heading level0 col0" >icao</th>
#       <th id="T_dded7_level0_col1" class="col_heading level0 col1" >iata</th>
#       <th id="T_dded7_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_dded7_level0_col3" class="col_heading level0 col3" >state</th>
#       <th id="T_dded7_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_dded7_level0_col5" class="col_heading level0 col5" >country_code</th>
#       <th id="T_dded7_level0_col6" class="col_heading level0 col6" >lat</th>
#       <th id="T_dded7_level0_col7" class="col_heading level0 col7" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dded7_row0_col0" class="data row0 col0" >xxxx</td>
#       <td id="T_dded7_row0_col1" class="data row0 col1" >IBZ</td>
#       <td id="T_dded7_row0_col2" class="data row0 col2" >Ibiza Airport</td>
#       <td id="T_dded7_row0_col3" class="data row0 col3" ></td>
#       <td id="T_dded7_row0_col4" class="data row0 col4" >Spain</td>
#       <td id="T_dded7_row0_col5" class="data row0 col5" >ES</td>
#       <td id="T_dded7_row0_col6" class="data row0 col6" >38.87</td>
#       <td id="T_dded7_row0_col7" class="data row0 col7" >1.27</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row1_col0" class="data row1 col0" >xxxx</td>
#       <td id="T_dded7_row1_col1" class="data row1 col1" >BRE</td>
#       <td id="T_dded7_row1_col2" class="data row1 col2" >Bremen Airport</td>
#       <td id="T_dded7_row1_col3" class="data row1 col3" ></td>
#       <td id="T_dded7_row1_col4" class="data row1 col4" >Germany</td>
#       <td id="T_dded7_row1_col5" class="data row1 col5" >DE</td>
#       <td id="T_dded7_row1_col6" class="data row1 col6" >53.05</td>
#       <td id="T_dded7_row1_col7" class="data row1 col7" >8.79</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row2_col0" class="data row2 col0" >xxxx</td>
#       <td id="T_dded7_row2_col1" class="data row2 col1" >BTK</td>
#       <td id="T_dded7_row2_col2" class="data row2 col2" >Bratsk Airport</td>
#       <td id="T_dded7_row2_col3" class="data row2 col3" ></td>
#       <td id="T_dded7_row2_col4" class="data row2 col4" >Russia</td>
#       <td id="T_dded7_row2_col5" class="data row2 col5" >RU</td>
#       <td id="T_dded7_row2_col6" class="data row2 col6" >56.38</td>
#       <td id="T_dded7_row2_col7" class="data row2 col7" >101.68</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row3_col0" class="data row3 col0" >xxxx</td>
#       <td id="T_dded7_row3_col1" class="data row3 col1" >xxx</td>
#       <td id="T_dded7_row3_col2" class="data row3 col2" >Ciudad Bolívar</td>
#       <td id="T_dded7_row3_col3" class="data row3 col3" ></td>
#       <td id="T_dded7_row3_col4" class="data row3 col4" >Venezuela</td>
#       <td id="T_dded7_row3_col5" class="data row3 col5" >VE</td>
#       <td id="T_dded7_row3_col6" class="data row3 col6" >8.14</td>
#       <td id="T_dded7_row3_col7" class="data row3 col7" >-64.74</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row4_col0" class="data row4 col0" >xxxx</td>
#       <td id="T_dded7_row4_col1" class="data row4 col1" >xxx</td>
#       <td id="T_dded7_row4_col2" class="data row4 col2" >Lobito Airport</td>
#       <td id="T_dded7_row4_col3" class="data row4 col3" ></td>
#       <td id="T_dded7_row4_col4" class="data row4 col4" >Angola</td>
#       <td id="T_dded7_row4_col5" class="data row4 col5" >AO</td>
#       <td id="T_dded7_row4_col6" class="data row4 col6" >-12.35</td>
#       <td id="T_dded7_row4_col7" class="data row4 col7" >13.53</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row5_col0" class="data row5 col0" >xxxx</td>
#       <td id="T_dded7_row5_col1" class="data row5 col1" >HGL</td>
#       <td id="T_dded7_row5_col2" class="data row5 col2" >Helgoland Airport</td>
#       <td id="T_dded7_row5_col3" class="data row5 col3" ></td>
#       <td id="T_dded7_row5_col4" class="data row5 col4" >Germany</td>
#       <td id="T_dded7_row5_col5" class="data row5 col5" >DE</td>
#       <td id="T_dded7_row5_col6" class="data row5 col6" >54.19</td>
#       <td id="T_dded7_row5_col7" class="data row5 col7" >7.92</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row6_col0" class="data row6 col0" >xxxx</td>
#       <td id="T_dded7_row6_col1" class="data row6 col1" >BLK</td>
#       <td id="T_dded7_row6_col2" class="data row6 col2" >Blackpool Airport</td>
#       <td id="T_dded7_row6_col3" class="data row6 col3" ></td>
#       <td id="T_dded7_row6_col4" class="data row6 col4" >United Kingdom</td>
#       <td id="T_dded7_row6_col5" class="data row6 col5" >GB</td>
#       <td id="T_dded7_row6_col6" class="data row6 col6" >53.77</td>
#       <td id="T_dded7_row6_col7" class="data row6 col7" >-3.03</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row7_col0" class="data row7 col0" >xxxx</td>
#       <td id="T_dded7_row7_col1" class="data row7 col1" >xxx</td>
#       <td id="T_dded7_row7_col2" class="data row7 col2" >Okha</td>
#       <td id="T_dded7_row7_col3" class="data row7 col3" ></td>
#       <td id="T_dded7_row7_col4" class="data row7 col4" >Russia</td>
#       <td id="T_dded7_row7_col5" class="data row7 col5" >RU</td>
#       <td id="T_dded7_row7_col6" class="data row7 col6" >53.59</td>
#       <td id="T_dded7_row7_col7" class="data row7 col7" >142.94</td>
#     </tr>
#     <tr>
#       <td id="T_dded7_row8_col0" class="data row8 col0" >xxxx</td>
#       <td id="T_dded7_row8_col1" class="data row8 col1" >xxx</td>
#       <td id="T_dded7_row8_col2" class="data row8 col2" >Socorro</td>
#       <td id="T_dded7_row8_col3" class="data row8 col3" >NM</td>
#       <td id="T_dded7_row8_col4" class="data row8 col4" >United States</td>
#       <td id="T_dded7_row8_col5" class="data row8 col5" >US</td>
#       <td id="T_dded7_row8_col6" class="data row8 col6" >34.06</td>
#       <td id="T_dded7_row8_col7" class="data row8 col7" >-106.89</td>
#     </tr>
#     <tr>
#       <td

# %% [markdown]
# # <br> **Section 5: Export DataFrames to CSV Files**

# %% [markdown]
# ## **5.1: Clean and Updated Aviation Accident Data**

# %%
cleanAviationAccidentsDataFrame \
    .to_csv \
        (local_constant.AVIATION_CLEAN_ACCIDENTS_DATA_CSV_FILE)

# %% [markdown]
# ## **5.2: Departure Airports**

# %%
departureAirportsDataFrame \
    .to_csv \
        (local_constant.AVIATION_DEPARTURE_AIRPORTS_CSV_FILE)

# %% [markdown]
# ## **5.3: Destination Airports**

# %%
destinationAirportsDataFrame \
    .to_csv \
        (local_constant.AVIATION_DESTINATION_AIRPORTS_CSV_FILE)

# %% [markdown]
# ## **5.4: Aviation Accident Locations**

# %%
aviationAccidentLocationsDataFrame \
    .to_csv \
        (local_constant.AVIATION_ACCIDENT_LOCATIONS_CSV_FILE)

# %%
#log_subroutine \
#    .EndProgramExecution()
